# %%
### Conditional Programming

# %%
num=1
if num>0:
    print("positive")
# Out:
# positive

# %%
num=-1
if num>0:
    print("Positive")

# %%
num=-19
if num>0:
    print("positive")
else:
    print("negative")
# Out:
# negative

# %%
num=-19
if num>0:
    print("positive")
elif num==0:
    print("zero")
else:
    print("negative")
# Out:
# negative

# %%
num=20
num
# Out:
# 20

# %%
age=20
if age<18:
    print("Young")
elif age>60:
    print("Senior_citizen")
else: print("Adult")
# Out:
# Adult

# %%
age=60
if age<18:
    print("Young")
elif age>60:
    print("Senior_citizen")
else: print("Adult")
# Out:
# Adult

# %%
age=66
if age<18:
    print("Young")
elif age>60:
    print("Senior_citizen")
else: print("Adult")
# Out:
# Senior_citizen

# %%
age=5
if age<18:
    print("Young")
elif age>60:
    print("Senior_citizen")
else: print("Adult")
# Out:
# Young

# %%
age=18
if age<18:
    print("Young")
elif age>60:
    print("Senior_citizen")
else: print("Adult")
# Out:
# Adult

# %%
age=26
if age<=5:
    print("No_Entry_fee")
elif age>60:
    print("No_Entry_fee")
elif age>25:
    print("Entry_Fee_is_25")
else:
    print("Entry_fee_is_20")
# Out:
# Entry_Fee_is_25

# %%
age=5
if age<=5:
    print("No_Entry_fee")
elif age>60:
    print("No_Entry_fee")
elif age>25:
    print("Entry_Fee_is_25")
else:
    print("Entry_fee_is_20")
# Out:
# No_Entry_fee

# %%
age=4
if age<=5:
    print("No_Entry_fee")
elif age>60:
    print("No_Entry_fee")
elif age>25:
    print("Entry_Fee_is_25")
else:
    print("Entry_fee_is_20")
# Out:
# No_Entry_fee

# %%
age=25
if age<=5:
    print("No_Entry_fee")
elif age>60:
    print("No_Entry_fee")
elif age>25:
    print("Entry_Fee_is_25")
else:
    print("Entry_fee_is_20")
# Out:
# Entry_fee_is_20

# %%
age=60
if age<=5:
    print("No_Entry_fee")
elif age>60:
    print("No_Entry_fee")
elif age>25:
    print("Entry_Fee_is_25")
else:
    print("Entry_fee_is_20")
# Out:
# Entry_Fee_is_25
