# %%
print("Hello World")
# Out:
# Hello World

# %%
print("NITASHREE")
# Out:
# NITASHREE

# %%
print(10)
# Out:
# 10

# %%
print(1.5)
# Out:
# 1.5

# %%
print('NITASHREE')
# Out:
# NITASHREE

# %%
x=5
x
# Out:
# 5

# %%
x=10.8
type(x)
# Out:
# float

# %%
x="NITA"
type(x)
# Out:
# str

# %%
z=True
type(z)
# Out:
# bool

# %% [markdown]
# ### Variables
# # Space is not allowed in variable names
# # variable names should not start with number
# # variable name should start with A-Z or a-z or _
# # The only special character allowed is _
#
# booknames=["python","r"]
# booknames

# %%
book names=["python","r"] # Space is not allowed in variable names
book names
# Out:
#   Cell In[14], line 1
#     book names=["python","r"]
#          ^
# SyntaxError: invalid syntax

# %%
2booknames=["python","r"] #variable names should not start with number
2booknames
# Out:
#   Cell In[15], line 1
#     2booknames=["python","r"]
#     ^
# SyntaxError: invalid decimal literal

# %%
book2names=["python","r"]
book2names
# Out:
# ['python', 'r']

# %%
book-names=["python","r"]
book-names
# Out:
#   Cell In[17], line 1
#     book-names=["python","r"]
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
book_names=["python","r"]
book_names
# Out:
# ['python', 'r']

# %% [markdown]
# ## DATA STUCTURES
# #List

# %%
a=[1,2,3,4,5,"python",True,10.5,21.3]
a
# Out:
# [1, 2, 3, 4, 5, 'python', True, 10.5, 21.3]

# %%
type(a)
# Out:
# list

# %%
a[0]  ### [0]->indexing
# Out:
# 1

# %%
a[4]
# Out:
# 5

# %%
a[8]
# Out:
# 21.3

# %%
a[-1]
# Out:
# 21.3

# %%
a[0:2] ##[0:2] -> Slicing
# Out:
# [1, 2]

# %%
a[5:8]
# Out:
# ['python', True, 10.5]

# %%
a[0]=100
a
# Out:
# [100, 2, 3, 4, 5, 'python', True, 10.5, 21.3]

# %% [markdown]
# ### List has elements separated by commas
# ### Heterogeneous-> Different data types like int,float,bool,and string
# ### Square brackets are used to create list
# ### The elements can be retrieved using index
# ### Mutable->once the list is created we can change the elements

# %%
a=(1,2,3,4,5,"python",True,10.5,21.3)
a
# Out:
# (1, 2, 3, 4, 5, 'python', True, 10.5, 21.3)

# %%
type(a)
# Out:
# tuple

# %%
a[0]
# Out:
# 1

# %%
a[0]=100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 a[0]=100
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ### In tuple , the elements are separated by commas *and it is enclosed with ()
# ### Elements can be retrieved using Index
# ### Immutable-> Once the tuple is created we cannot change elements.

# %% [markdown]
# ### Dictionary

# %%
b={1:"apple",2:"banana","oranges":3,2:"nita","apple":7}
b
# Out:
# {1: 'apple', 2: 'nita', 'oranges': 3, 'apple': 7}

# %%
b[1]
# Out:
# 'apple'

# %%
b[2]
# Out:
# 'nita'

# %% [markdown]
# ### Dictionary apper as key and value pairs
# ### Before: are keys and after: are values
# ### Key should be always unique but values can be duplicated
# ### if same keys is repeated it will consider lasT one
# ### Values can be retrieved using indexing.
